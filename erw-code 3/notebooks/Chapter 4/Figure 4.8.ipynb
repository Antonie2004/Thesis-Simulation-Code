# %%
"""
Figure 4.8 — Bachelor Thesis on the Elephant Random Walk.

Histograms of the rescaled ERW
        Z_n := S_n / (n^alpha * Gamma(alpha+1)^{-1}) - beta,   alpha = 2p - 1,
over 15,000 paths at n = 5,000,
for p in {0.80, 0.95, 0.99} (top to bottom, i.e. rows)
and q in {0.25, 0.50, 0.75} (columns: teal, sand, red).

Within each row (fixed p) the three panels share x- and y-limits so that the
effect of q on the shape of the limiting distribution is directly comparable.
Across rows, the y-scale is allowed to adapt to p, since the distributions
collapse sharply as p -> 1.
"""

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from scipy.special import gammaln

# ── Fonts ─────────────────────────────────────────────────────────────────────
plt.rcParams.update({
    "text.usetex":        False,
    "font.family":        "serif",
    "font.serif":         ["Palatino", "Palatino Linotype", "Georgia",
                           "Times New Roman", "DejaVu Serif"],
    "mathtext.fontset":   "cm",
    "axes.labelsize":     9,
    "axes.titlesize":     9,
    "xtick.labelsize":    8,
    "ytick.labelsize":    8,
    "figure.dpi":         150,
})

# ── Thesis palette (matching the 9-panel figure of Section 4.2.3) ─────────────
TEAL = ( 30/255, 130/255, 130/255)   # q = 0.25
SAND = (184/255, 146/255,  58/255)   # q = 0.50
RED  = (177/255,  56/255,  69/255)   # q = 0.75

Q_VALUES = [0.25, 0.50, 0.75]
Q_COLORS = [TEAL, SAND, RED]
P_VALUES = [0.80, 0.95, 0.99]

# ── Bar colour helpers (pale toward the tails) ────────────────────────────────
def _bar_color(rgb, x, x_max, pale_mix=0.72):
    t = min(abs(x) / x_max, 1.0) if x_max > 0 else 0.0
    return tuple(c + (1 - c) * pale_mix * t for c in rgb)

def _edge_color(rgb, x, x_max, pale_mix=0.35):
    t = min(abs(x) / x_max, 1.0) if x_max > 0 else 0.0
    return tuple(c + (1 - c) * pale_mix * t for c in rgb)

# ── ERW simulator ────────────────────────────────────────────────────────────
def simulate_erw_batch(n, p, q, n_sims, rng=None):
    """Simulate n_sims ERW paths of length n and return the final positions S_n."""
    if rng is None:
        rng = np.random.default_rng()
    xi = np.zeros((n_sims, n + 1), dtype=np.int8)
    xi[:, 1] = np.where(rng.random(n_sims) < q, 1, -1)
    for t in range(1, n):
        idx  = rng.integers(1, t + 1, size=n_sims)
        past = xi[np.arange(n_sims), idx]
        flip = np.where(rng.random(n_sims) < p, 1, -1)
        xi[:, t + 1] = past * flip
    return xi[:, 1:].sum(axis=1).astype(float)

# ── Parameters (Figure 4.8) ───────────────────────────────────────────────────
N_STEPS = 5_000
N_SIMS  = 15_000
N_BINS  = 52

rng = np.random.default_rng(2026)

# ── Simulate all nine combinations ────────────────────────────────────────────
finals = {}   # (p, q) -> Z_n sample
for p_val in P_VALUES:
    alpha = 2 * p_val - 1
    scale = np.exp(alpha * np.log(N_STEPS) - gammaln(alpha + 1))
    for q_val in Q_VALUES:
        beta = 2 * q_val - 1
        raw  = simulate_erw_batch(N_STEPS, p=p_val, q=q_val, n_sims=N_SIMS, rng=rng)
        finals[(p_val, q_val)] = raw / scale - beta

# ── Per-row axis limits ───────────────────────────────────────────────────────
# For each row (fixed p), pick an x-range that covers all three q-samples,
# and a shared y-max from all three histograms.
row_xlim = {}   # p -> x_lim (symmetric around 0)
row_ylim = {}   # p -> y_max
row_bin_edges = {}
row_counts = {} # (p, q) -> counts

for p_val in P_VALUES:
    # Use a robust quantile for x-limit (99th percentile of |Z_n| across all q)
    all_abs = np.concatenate([np.abs(finals[(p_val, q)]) for q in Q_VALUES])
    xlim = float(np.quantile(all_abs, 0.995)) * 1.05
    # Round a little for neat ticks
    xlim = np.ceil(xlim * 10) / 10
    row_xlim[p_val] = xlim

    edges = np.linspace(-xlim, xlim, N_BINS + 1)
    row_bin_edges[p_val] = edges

    ymax = 0.0
    for q_val in Q_VALUES:
        c, _ = np.histogram(finals[(p_val, q_val)], bins=edges, density=True)
        row_counts[(p_val, q_val)] = c
        ymax = max(ymax, c.max())
    row_ylim[p_val] = ymax * 1.08

# ── Plot ──────────────────────────────────────────────────────────────────────
fig, axes = plt.subplots(3, 3, figsize=(7.2, 7.8))
fig.subplots_adjust(left=0.09, right=0.98, bottom=0.06, top=0.93,
                    wspace=0.28, hspace=0.85)

LABEL_GREY = (0.55, 0.55, 0.55)

def _nice_xticks(xlim):
    """Choose three symmetric x-ticks: -t, 0, t with t = round to 1 dp."""
    t = np.round(xlim * 0.75, 1)
    # Avoid 0 tick colliding with end
    if t <= 0:
        t = np.round(xlim * 0.5, 1)
    return [-t, 0.0, t]

for i, p_val in enumerate(P_VALUES):
    xlim   = row_xlim[p_val]
    ymax   = row_ylim[p_val]
    edges  = row_bin_edges[p_val]
    width  = edges[1] - edges[0]
    centers = 0.5 * (edges[:-1] + edges[1:])
    xticks = _nice_xticks(xlim)

    for j, (q_val, color) in enumerate(zip(Q_VALUES, Q_COLORS)):
        ax = axes[i, j]
        counts = row_counts[(p_val, q_val)]

        for xc, h in zip(centers, counts):
            ax.bar(xc, h, width=width,
                   color=_bar_color(color, xc, xlim),
                   edgecolor=_edge_color(color, xc, xlim),
                   linewidth=0.28, alpha=0.70, zorder=2)

        ax.set_xlabel(r"$Z_n$", labelpad=2)
        ax.set_xlim(-xlim, xlim)
        ax.set_ylim(0, ymax)

        ax.spines["top"].set_visible(False)
        ax.spines["right"].set_visible(False)
        ax.spines["left"].set_linewidth(0.55)
        ax.spines["bottom"].set_linewidth(0.55)
        ax.tick_params(width=0.55, length=3, direction="out")

        ax.xaxis.set_major_locator(ticker.FixedLocator(xticks))
        def _fmt(t, _, ticks=xticks):
            # Clean formatting: int where possible, else 1 dp
            if t == 0:
                return r"$0$"
            s = f"{t:g}"
            return fr"${s}$"
        ax.xaxis.set_major_formatter(ticker.FuncFormatter(_fmt))
        ax.yaxis.set_major_locator(ticker.MaxNLocator(nbins=3))

        # Only leftmost column shows the y-label and y-tick labels
        if j == 0:
            ax.set_ylabel("Density", labelpad=4, fontsize=8)
        else:
            ax.tick_params(axis="y", labelleft=False)

# ── Row (p) and column (q) labels, no collisions ──────────────────────────────
# Strategy: put the p-label high above each row (just below the top of the
# previous row's panels, or above the first row's top), and the q-labels just
# above each row's panels.
P_LABEL_OFFSET = 0.040   # vertical offset above panel top for the p-label
Q_LABEL_OFFSET = 0.007   # vertical offset above panel top for the q-label

for i, p_val in enumerate(P_VALUES):
    row_top = axes[i, 1].get_position().y1
    # p label (centered over the whole row)
    fig.text(0.5, row_top + P_LABEL_OFFSET, fr"$p\!=\!{p_val:.2f}$",
             ha="center", va="bottom", fontsize=9.5, color=LABEL_GREY)
    # q labels over each column of this row
    for j, q_val in enumerate(Q_VALUES):
        col_x = 0.5 * (axes[i, j].get_position().x0 + axes[i, j].get_position().x1)
        fig.text(col_x, row_top + Q_LABEL_OFFSET, fr"$q\!=\!{q_val:.2f}$",
                 ha="center", va="bottom", fontsize=8.5, color=LABEL_GREY)

fig.savefig("figure_4_8.pdf", bbox_inches="tight", pad_inches=0.02)
print("Saved figure_4_8.pdf")
